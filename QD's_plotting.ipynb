# %% [markdown]
# <a href="https://colab.research.google.com/github/Luke-Williams-01/Luke-Williams-01/blob/main/QD's_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading in the data and plotting 

I704100 = pd.read_csv('704 QDs on InP 530C 0.01s 100%.csv')
print(I704100)
'''
print(I704100['900.02732455394334'])
print(I704100['62716'])
a = I704100['900.02732455394334']
b = I704100['62716']
'''
I704100.plot()
# Out:
#       900.02732455394334  62716
# 0             900.201773  71702
# 1             900.376222  60977
# 2             900.550670  74863
# 3             900.725119  66177
# 4             900.899568  63416
# ...                  ...    ...
# 4604         1699.318985  70242
# 4605         1699.491754  64185
# 4606         1699.664523  73293
# 4607         1699.837292  71174
# 4608         1700.010060  65644
#
# [4609 rows x 2 columns]

# %%
with open("704 QDs on InP 530C 0.01s 100%.csv") as file_name:
    array704100 = np.loadtxt('704 QDs on InP 530C 0.01s 100%.csv', delimiter=",")

print(array704100)

I704100, W704100 = np.split(array704100, 2, axis = 1)

plt.plot(I704100, W704100)
# Out:
# [[  900.02732455 62716.        ]
#  [  900.20177314 71702.        ]
#  [  900.37622176 60977.        ]
#  ...
#  [ 1699.66452347 73293.        ]
#  [ 1699.83729204 71174.        ]
#  [ 1700.01006015 65644.        ]]
